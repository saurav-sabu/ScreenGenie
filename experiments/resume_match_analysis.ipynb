# %%
from langchain_google_genai import GoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_community.document_loaders import PyPDFLoader
import pymupdf4llm

from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
md_text = pymupdf4llm.to_markdown("data/Saurav_Sabu_Resume.pdf")
md_text
# Out:
# Processing data/Saurav_Sabu_Resume.pdf...
# [                                        ] (0/1=======================================[========================================] (1/1)
# ]
# 'Keras\n\nMySQL\n\nLangchain\n\n\n## C G P A : 9 . 43\n\n**Percentage: 89.6%**\n\n**Board: Mumbai University**\n\nCGPA: 9.43\nBoard: Mumbai University\n\n**Deep Learning**\n\n**Machine Learning**\n\nBoard: CBSE\nBoard: CBSE\n\n## G e n e r ative AI\n\nMachine Learning\nDeep Learning\nNavi Mumbai, India\n12/23 - Current\nConducted Functional Testing of APIs across multiple projects.\nDocumented and reported software defects through the Azure portal\nAssisted team members in creating comprehensive test cases based on user stories.\nCompleted unit and regression tests on software and individual modules.\nFlask\n1. LegalSetu - Legal Decision Support System:\n\n## P y t h o n\n\nDeveloped a smart legal assistant us\ning generative AI and RAG (Retrieval-Augmented Generation) to provide real-time legal insights and document drafting support. Implemented using LangChain, Google Gemini API, and vector databases for efficient legal information retrieval and natural language understanding.\n2. Source Code Analysis:\n\n\n# SAURAV SABU\n\n## C A R E E R O B J E C T I V E\n\nsaurav.sabu9@gma il.c om\n\n## E X P E R I E N C E\n\n**JIO Platforms Limited - Associate QA Engineer**\n\nGit & GitHub\n\nFlask\n\n8451842018\n\nNavi Mumbai, Ma harashtra 410206\n\nAssisted team members in creating comprehensive test\ncases based on user stories.\nCompleted unit and regression tests on software and\nindividual modules.\n\n## M o n g o D B\n\n**https://github.com/saurav-sabu**\nDeveloped a smart legal assistant using generative AI and RAG\n(Retrieval-Augmented Generation) to provide real-time legal\ninsights and document drafting support. Implemented using\nLangChain, Google Gemini API, and vector databases for efficient\nlegal information retrieval and natural language understanding.\n\n**2. Source Code Analysis:**\nhttps://www.linkedin.com/in/sauravsabu789/\n\n**3. Document QA System:**\nDetail-oriented and analytical QA engineer with experience in sof\ntware test ing and qualit y as sura nce, trans itioni ng in\nto data s cien ce with a focus o n ge nerative A I. P roficien\nt in data analysis, machine learning, and statistical modeling usi\nng ython, SQL, and AI-driven\n\n\n-----\n\n'

# %%
job_description = '''
1-3 years of experience in data science field
An advanced degree in engineering, computer science, statistics or related field is preferred
Expertise with either Python or Java is essential, while experience with both is desirable; other programming language skills are highly desirable. Experience with Python packages like pandas, scikit-learn, TensorFlow, numpy, NLTK is a plus.
Basic knowledge of statistical/ML/AI algorithms
Experience with DevOps tools (e.g. Splunk, Git, uDeploy, Jenkins, Control-M) is desirable
Experience with Agile software engineering practices
Experience with back-end XML, relational, and file-based databases (e.g. SQL, Postgres, Redshift, Netezza, HDFS)
Experience developing and deploying solutions using services in the Amazon AWS ecosystem (Lambda, EC2, RDS, EMR)
Experience with the Hadoop stack (MapReduce, Pig, Hive, Nifi, Spark) is desirable
Experience with at least one statistical modeling language (e.g. R, MATLAB, Python)
'''

# %%
resume_job_description_prompt = """
Act as an advanced ATS (Applicant Tracking System) evaluator with expertise in analyzing resumes for technical and competitive roles in fields like:
- Software Engineering
- Data Science
- Data Analysis
- Big Data Engineering
- Software Testing
- DevOps
- Cloud Engineering
- Cybersecurity
- Machine Learning Engineering
- AI Engineering
- Blockchain Engineering
- Quantum Computing
- Full Stack Development
- Frontend Development
- Backend Development
- Mobile Development
- Game Development

Evaluate the provided resume against the given job description, considering:
1. Keyword and skill alignment.
2. Relevance of experience and achievements to the job requirements.
3. Overall compatibility with the job description based on ATS criteria.

Perform the following analysis and respond in the specified JSON format:

### Inputs:
- Resume: {resume_text}
- Job Description: {job_description}

### Output JSON Format:
{{
    "JD Match": "percentage between 0-100",
    "MissingKeywords": ["keyword1", "keyword2", ...],
    "Profile Summary": "Provide a detailed evaluation of how well the resume aligns with the job description, highlighting strengths, gaps, and specific improvement suggestions to optimize ATS performance."
}}

### Guidelines for Analysis:
- **JD Match**: Use semantic similarity techniques to calculate a compatibility percentage between the resume and the job description.
- **Missing Keywords**: Extract critical skills, tools, or technologies mentioned in the job description but absent in the resume.
- **Profile Summary**: Include an overview of the alignment between the candidate’s profile and job requirements, such as relevant skills, achievements, and areas needing enhancement.

Make your response clear, actionable, and tailored to a highly competitive job market.
"""

# %%
prompt = ChatPromptTemplate.from_template(resume_job_description_prompt)

# %%
model = GoogleGenerativeAI(model="gemini-1.5-pro-latest")
chain = prompt | model | StrOutputParser()

# %%
resume_text = md_text
job_description = job_description

# %%
result = chain.invoke({"resume_text": resume_text, "job_description": job_description})
print(result)
# Out:
# ```json
# {
#   "JD Match": 65,
#   "MissingKeywords": ["Java", "scikit-learn", "TensorFlow", "NLTK", "Splunk", "uDeploy", "Jenkins", "Control-M", "Agile", "XML", "Postgres", "Redshift", "Netezza", "HDFS", "Lambda", "EC2", "RDS", "EMR", "MapReduce", "Pig", "Hive", "Nifi", "Spark", "MATLAB", "R"],
#   "Profile Summary": "The candidate's resume demonstrates some alignment with the data science job description, particularly in areas like Python programming, experience with LangChain and generative AI, and database experience with MongoDB and MySQL. The candidate's academic background with a high CGPA also suggests a strong analytical foundation.  However, the resume lacks explicit mention of several key skills and technologies required for the role.  \n\n**Strengths:**\n* Demonstrated experience with Python, a core requirement for the job.\n* Experience with LangChain, Generative AI, and RAG, which are highly relevant to modern data science applications.\n* Familiarity with databases (MySQL, MongoDB).\n* Strong academic performance (high CGPA).\n* Experience with Flask, suggesting some backend development skills.\n\n**Gaps:**\n* Missing explicit mention of experience with key Python libraries like scikit-learn, TensorFlow, numpy, and NLTK. While the candidate may possess these skills, explicitly mentioning them is crucial for ATS compatibility.\n* Lack of experience with Java, another desirable skill mentioned in the job description.\n* No mention of experience with DevOps tools, Agile methodologies, or cloud platforms like AWS and its services (Lambda, EC2, RDS, EMR). \n* Missing experience with the Hadoop ecosystem (MapReduce, Pig, Hive, Nifi, Spark), which is desirable for this role.\n*  Lack of explicit mention of statistical modeling languages like R or MATLAB.\n* While QA experience is listed, the resume needs to connect this experience more directly to data science applications and highlight transferable skills like data analysis and problem-solving. \n\n**Improvement Suggestions:**\n* **Keyword Optimization:** Incorporate missing keywords throughout the resume, especially in the skills section and experience descriptions. Quantify experience with these technologies whenever possible (e.g., \"2 years of experience using scikit-learn for machine learning model development\").\n* **Highlight Transferable Skills:**  Emphasize how QA experience translates to relevant data science skills. For example, describe how testing involved data analysis, identifying patterns, or problem-solving.\n* **Project Portfolio:** Showcase data science projects on platforms like GitHub to demonstrate practical skills and experience with relevant tools and technologies.  Include clear descriptions of the projects, methodologies used, and results achieved.\n* **Tailor to the Job Description:** Carefully review the job description and customize the resume to mirror its language and requirements.  This will improve ATS matching scores.\n* **Structure and Formatting:** Improve the resume's structure and formatting for better readability and ATS parsing.  Use clear headings, bullet points, and concise language. Avoid unusual formatting and special characters that can confuse ATS software."
# }
# ```
